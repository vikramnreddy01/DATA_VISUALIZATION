# %% [markdown]
# #### Develop a code to plot different comparison plots and composition plots considering any suitable dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Iris dataset
df = sns.load_dataset('iris')

# %%
# Comparison Plot: Pairplot
sns.pairplot(df, hue='species')
plt.title("Pairplot of Iris Data")
plt.show()

# %%
# Comparison Plot: Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='species', y='sepal_length', data=df)
plt.title("Boxplot of Sepal Length by Species")
plt.show()

# %%
# Comparison Plot: Violin Plot
plt.figure(figsize=(10, 6))
sns.violinplot(x='species', y='petal_length', data=df)
plt.title("Violin Plot of Petal Length by Species")
plt.show()

# %%
# Composition Plot: Pie Chart 
species_counts = df['species'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(species_counts, labels=species_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Proportion of Each Species in Iris Dataset")
plt.show()

# %%
# Composition Plot: Stacked Bar Plot
species_means = df.groupby('species').mean().reset_index()
species_means.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title("Stacked Bar Plot of Mean Measurements by Species")
plt.xlabel('Species')
plt.ylabel('Mean Values')
plt.legend(loc='best')
plt.show()
